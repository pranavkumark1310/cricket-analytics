# %% [markdown]
# ## Import Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %%
df1 = pd.read_csv('IPL Matches 2008-2020.csv')
df1
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
df1.describe()
# Out:
#                  id  neutral_venue  result_margin
# count  8.160000e+02     816.000000     799.000000
# mean   7.563496e+05       0.094363      17.321652
# std    3.058943e+05       0.292512      22.068427
# min    3.359820e+05       0.000000       1.000000
# 25%    5.012278e+05       0.000000       6.000000
# 50%    7.292980e+05       0.000000       8.000000
# 75%    1.082626e+06       0.000000      19.500000
# max    1.237181e+06       1.000000     146.000000

# %%
df1.isnull().sum()
# Out:
# id                   0
# city                13
# date                 0
# player_of_match      4
# venue                0
# neutral_venue        0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# winner               4
# result               4
# result_margin       17
# eliminator           4
# method             797
# umpire1              0
# umpire2              0
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Dropping columns

# %%
df3 = df1.drop(columns=['method', 'result_margin', 'eliminator'])

# %%
## checking null entries in the dataset

df3[df3['city'].isnull()]
# Out:
#          id city        date player_of_match  \
# 399  729281  NaN  2014-04-17       YS Chahal
# 402  729287  NaN  2014-04-19        PA Patel
# 403  729289  NaN  2014-04-19       JP Duminy
# 404  729291  NaN  2014-04-20      GJ Maxwell
# 406  729295  NaN  2014-04-22      GJ Maxwell
# 407  729297  NaN  2014-04-23       RA Jadeja
# 408  729299  NaN  2014-04-24         CA Lynn
# 409  729301  NaN  2014-04-25        AJ Finch
# 410  729303  NaN  2014-04-25       MM Sharma
# 413  729309  NaN  2014-04-27         M Vijay
# 414  729311  NaN  2014-04-27        DR Smith
# 415  729313  NaN  2014-04-28  Sandeep Sharma
# 417  729317  NaN  2014-04-30         B Kumar
#
#                                    venue  neutral_venue  \
# 399              Sharjah Cricket Stadium              1
# 402  Dubai International Cricket Stadium              1
# 403  Dubai International Cricket Stadium              1
# 404              Sharjah Cricket Stadium              1
# ...

# %%
df3[df3['winner'].isnull()]
# Out:
#           id       city        date player_of_match                  venue  \
# 241   501265      Delhi  2011-05-21             NaN       Feroz Shah Kotla
# 486   829763  Bangalore  2015-04-29             NaN  M Chinnaswamy Stadium
# 511   829813  Bangalore  2015-05-17             NaN  M Chinnaswamy Stadium
# 744  1178424  Bengaluru  2019-04-30             NaN  M.Chinnaswamy Stadium
#
#      neutral_venue                        team1             team2  \
# 241              0             Delhi Daredevils     Pune Warriors
# 486              0  Royal Challengers Bangalore  Rajasthan Royals
# 511              0  Royal Challengers Bangalore  Delhi Daredevils
# 744              0  Royal Challengers Bangalore  Rajasthan Royals
#
#                      toss_winner toss_decision winner result          umpire1  \
# 241             Delhi Daredevils           bat    NaN    NaN        SS Hazare
# 486             Rajasthan Royals         field    NaN    NaN        JD Cloete
# ...

# %% [markdown]
# ## IPL Matches analytics

# %% [markdown]
# ### Data Cleaning

# %%
df3['city'].fillna(df3['venue'], inplace=True)
df3['player_of_match'].fillna('Unknown', inplace=True)
df3['winner'].fillna('No Result', inplace=True)
df3['result'].fillna('No Result', inplace=True)

# %%
df3.team1.replace({'Rising Pune Supergiants' : 'Rising Pune Supergiant'},regex=True,inplace=True)
df3.team2.replace({'Rising Pune Supergiants' : 'Rising Pune Supergiant'},regex=True,inplace=True)
df3.winner.replace({'Rising Pune Supergiants' : 'Rising Pune Supergiant'},regex=True,inplace=True)
df3.venue.replace({'Feroz Shah Kotla Ground':'Feroz Shah Kotla',
                    'M Chinnaswamy Stadium':'M. Chinnaswamy Stadium',
                    'MA Chidambaram Stadium, Chepauk':'M.A. Chidambaram Stadium',
                     'M. A. Chidambaram Stadium':'M.A. Chidambaram Stadium',
                     'Punjab Cricket Association IS Bindra Stadium, Mohali':'Punjab Cricket Association Stadium',
                     'Punjab Cricket Association Stadium, Mohali':'Punjab Cricket Association Stadium',
                     'IS Bindra Stadium':'Punjab Cricket Association Stadium',
                    'Rajiv Gandhi International Stadium, Uppal':'Rajiv Gandhi International Stadium',
                    'Rajiv Gandhi Intl. Cricket Stadium':'Rajiv Gandhi International Stadium'},regex=True,inplace=True)

# %%
df3.isnull().sum()
# Out:
# id                 0
# city               0
# date               0
# player_of_match    0
# venue              0
# neutral_venue      0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# winner             0
# result             0
# umpire1            0
# umpire2            0
# dtype: int64

# %%
df3.size
# Out:
# 11424

# %%
df3.shape
# Out:
# (816, 14)

# %%
df3
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                    venue  neutral_venue  \
# 0                 M. Chinnaswamy Stadium              0
# 1     Punjab Cricket Association Stadium              0
# 2                       Feroz Shah Kotla              0
# 3                       Wankhede Stadium              0
# ...

# %% [markdown]
# ### Total number of matches at different Stadiums

# %%
venue_list = df3['venue'].value_counts()
venue_list.plot(kind='barh', figsize=(12,8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Total number of matches at different cities

# %%
city_list = df3['city'].value_counts()
city_list.plot(kind='barh', figsize=(12,8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Team wise total number of wins in IPL

# %% [markdown]
# #### i. Horizontal bar graph

# %%
winner = df3['winner'].value_counts()
winner.plot(kind='barh', figsize=(12,8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### ii. Pie Chart

# %%
winner = df3['winner'].value_counts()
winner.plot(kind='pie', figsize=(15,10))
# Out:
# <AxesSubplot:ylabel='winner'>

# %% [markdown]
# #### Adding ipl edition year in dataframe

# %%
match_year = pd.to_datetime(df3['date'])
df3['edition'] = match_year.dt.year

# %%
df3
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                    venue  neutral_venue  \
# 0                 M. Chinnaswamy Stadium              0
# 1     Punjab Cricket Association Stadium              0
# 2                       Feroz Shah Kotla              0
# 3                       Wankhede Stadium              0
# ...

# %% [markdown]
# ### Total number of matches year wise (from 2008-2020)

# %%
year_num_matches = df3['edition'].value_counts()
year_num_matches.plot(kind='bar', figsize=(12,8), xlabel='Year from 2008-2020', ylabel='Number of matches')
# Out:
# <AxesSubplot:xlabel='Year from 2008-2020', ylabel='Number of matches'>

# %% [markdown]
# ### Teams who won the toss number of times

# %%
toss_win_teams = df3['toss_winner'].value_counts()

# %% [markdown]
# #### i. barh plot

# %%
toss_win_teams.plot(kind='barh', figsize=(12,8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### ii. pie chart

# %%
toss_win_teams.plot(kind='pie', figsize=(12,8))
# Out:
# <AxesSubplot:ylabel='toss_winner'>

# %% [markdown]
# ### Teams who won the toss and won the game

# %%
def team_win_toss_game(team_name):
    res = {}
    count = 0
    for index,data in df3.iterrows():
        if data['toss_winner'] == team_name and data['winner'] == team_name:
            count += 1
            res.update({'team': team_name, 'wins': count})
    return res

# %%
def list_of_teams():
    teams = []
    for index,data in df3.iterrows():
        teams.append(data['team1'])
    
    teams = set(teams)
    teams = list(teams)
    return teams

# %%
def win_toss_analysis():
    teams = list_of_teams()
    temp = []
    for team in teams:
        res = team_win_toss_game(team)
        temp.append(res)
    
    teams = []
    wins = []
    for data in temp:
        teams.append(data['team'])
        wins.append(data['wins'])
    
    figure(figsize=(12,10), dpi=80)
    plt.barh(teams, wins)
    plt.title('Number of matches won by teams batting first')
    plt.xlabel('Number of Matches')
    plt.ylabel('Teams')
    plt.show()

win_toss_analysis()

# %% [markdown]
# ### Most MOM awards

# %%
def mom_awards(number_of_players):
    mom_awards = df3['player_of_match'].value_counts()
    top_10_awards = mom_awards[:number_of_players]
    top_10_awards.plot(kind='bar', figsize=(12,8))

# %%
mom_awards(3)

# %%
mom_awards(10)

# %% [markdown]
# ### Team win percentage at particular venue

# %%
print(set(df3['venue']))
# Out:
# {'M.Chinnaswamy Stadium', 'Feroz Shah Kotla', 'Himachal Pradesh Cricket Association Stadium', 'Kingsmead', 'Green Park', 'M.A. Chidambaram Stadium', 'Eden Gardens', 'Shaheed Veer Narayan Singh International Stadium', 'JSCA International Stadium Complex', 'Saurashtra Cricket Association Stadium', 'Vidarbha Cricket Association Stadium, Jamtha', 'Dr DY Patil Sports Academy', 'Holkar Cricket Stadium', 'Brabourne Stadium', 'Subrata Roy Sahara Stadium', 'Sheikh Zayed Stadium', "St George's Park", 'Sardar Patel Stadium, Motera', 'Barabati Stadium', 'Nehru Stadium', 'Punjab Cricket Association Stadium', 'Sawai Mansingh Stadium', 'New Wanderers Stadium', 'OUTsurance Oval', 'Rajiv Gandhi International Stadium', 'Buffalo Park', 'Dubai International Cricket Stadium', 'Newlands', 'SuperSport Park', 'De Beers Diamond Oval', 'M. Chinnaswamy Stadium', 'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium', 'Wankhede Stadium', 'Sharjah Cricket Stadium', 'Maharashtra Cricket Association Stadium'}

# %%
def team_home_wins(team_name, venue_name):
    total_matches_at_venue = 0
    total_wins_at_venue = 0
    team_wins = {}
    for index,data in df3.iterrows():
        if data['venue'] == venue_name and (data['team1'] == team_name or data['team2'] == team_name):
            total_matches_at_venue += 1
    
    for index,data in df3.iterrows():
        if data['venue'] == venue_name and data['winner'] == team_name:
            total_wins_at_venue += 1
            win_percentage = (total_wins_at_venue / total_matches_at_venue) * 100
            team_wins.update({'team': team_name, 'venue': venue_name, 'wins': total_wins_at_venue, 'win_percentage': win_percentage})
    
    return team_wins

# %%
team_home_wins('Chennai Super Kings', 'M. Chinnaswamy Stadium')
# Out:
# {'team': 'Chennai Super Kings',
#  'venue': 'M. Chinnaswamy Stadium',
#  'wins': 4,
#  'win_percentage': 57.14285714285714}

# %%
team_home_wins('Royal Challengers Bangalore', 'M. Chinnaswamy Stadium')
# Out:
# {'team': 'Royal Challengers Bangalore',
#  'venue': 'M. Chinnaswamy Stadium',
#  'wins': 29,
#  'win_percentage': 47.540983606557376}

# %%
team_home_wins('Chennai Super Kings', 'M.A. Chidambaram Stadium')
# Out:
# {'team': 'Chennai Super Kings',
#  'venue': 'M.A. Chidambaram Stadium',
#  'wins': 40,
#  'win_percentage': 71.42857142857143}

# %% [markdown]
# ### Number of times teams who have won the toss

# %%
def team_win_toss(team_name):
    res = {}
    count = 0
    for index,data in df3.iterrows():
        if data['toss_winner'] == team_name:
            count += 1
            res.update({'team': team_name, 'toss_win': count})
    return res

# %%
def win_toss():
    teams = list_of_teams()
    temp = []
    for team in teams:
        res = team_win_toss(team)
        temp.append(res)
    
    teams = []
    wins = []
    for data in temp:
        teams.append(data['team'])
        wins.append(data['toss_win'])
    
    figure(figsize=(12,10), dpi=80)
    plt.barh(teams, wins)
    plt.title('Number of times winning the toss')
    plt.xlabel('Number of times winning the toss')
    plt.ylabel('Teams')
    plt.show()

win_toss()

# %% [markdown]
# ## Players and Ball by ball analytics

# %%
df2 = pd.read_csv('IPL Ball-by-Ball 2008-2020.csv')
df2
# Out:
#              id  inning  over  ball      batsman  non_striker  \
# 0        335982       1     6     5   RT Ponting  BB McCullum
# 1        335982       1     6     6  BB McCullum   RT Ponting
# 2        335982       1     7     1  BB McCullum   RT Ponting
# 3        335982       1     7     2  BB McCullum   RT Ponting
# 4        335982       1     7     3   RT Ponting  BB McCullum
# ...         ...     ...   ...   ...          ...          ...
# 193463  1237181       1    12     5      RR Pant      SS Iyer
# 193464  1237181       1    12     6      RR Pant      SS Iyer
# 193465  1237181       1    13     1      RR Pant      SS Iyer
# 193466  1237181       1    13     2      RR Pant      SS Iyer
# 193467  1237181       1    13     3      SS Iyer      RR Pant
#
#                  bowler  batsman_runs  extra_runs  total_runs  non_boundary  \
# 0             AA Noffke             1           0           1             0
# ...
